# %%
import requests
import pandas as pd

# %%
res = requests.get("http://lotto.auzonet.com/RK.php")
res.encoding = 'utf-8'
f = open('test.html', 'w', encoding='utf-8')
f.write(res.text)
f.close()
dfs = pd.read_html('test.html')
dfs[10]
dfs = dfs[10]
df
# Out:
#             01   02   03   04   05   06   07   08   09    10  ...    71    72  \
# 期數                                                            ...
# 108073590  NaN  2.0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  10.0  ...   NaN   NaN
# 108073589  NaN  NaN  NaN  NaN  NaN  NaN  7.0  NaN  NaN   NaN  ...  71.0   NaN
# 108073588  NaN  NaN  NaN  NaN  NaN  6.0  7.0  NaN  NaN   NaN  ...   NaN   NaN
# 108073587  1.0  2.0  3.0  4.0  NaN  NaN  NaN  8.0  NaN   NaN  ...   NaN   NaN
# 108073586  NaN  NaN  3.0  4.0  NaN  NaN  7.0  8.0  NaN  10.0  ...   NaN   NaN
# 108073585  NaN  2.0  3.0  4.0  NaN  NaN  NaN  8.0  9.0  10.0  ...   NaN   NaN
# 108073584  NaN  NaN  NaN  NaN  5.0  NaN  NaN  NaN  NaN   NaN  ...  71.0   NaN
# 108073583  1.0  2.0  NaN  NaN  NaN  6.0  NaN  NaN  NaN   NaN  ...   NaN   NaN
# 108073582  1.0  NaN  3.0  4.0  NaN  NaN  NaN  NaN  NaN   NaN  ...  71.0   NaN
# 108073581  NaN  NaN  3.0  NaN  NaN  NaN  7.0  NaN  NaN   NaN  ...  71.0  72.0
# ...

# %%
df.to_csv('bingo.csv', encoding='utf_8_sig')

# 讀檔
# 我們指名 index 為 證券代號
df = pd.read_csv('bingo.csv', index_col=['期數'])
