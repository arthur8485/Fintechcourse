# %%
from finlab.crawler import (
    widget, 
    
    crawl_price, 
    crawl_monthly_report, 
    crawl_finance_statement_by_date,
    
    date_range, month_range, season_range
)

import sqlite3
import os
conn = sqlite3.connect(os.path.join('data', "data.db"))

widget(conn, 'price', crawl_price, date_range)
widget(conn, 'monthly_revenue', crawl_monthly_report, month_range)
widget(conn, 'finance_statement', crawl_finance_statement_by_date, season_range)
# Out:
# VBox(children=(Label(value='price (from 2008-02-12 to 2019-12-27)'), HBox(children=(DatePicker(value=datetime.…
# VBox(children=(Label(value='monthly_revenue (from 2008-02-10 to 2019-12-10)'), HBox(children=(DatePicker(value…
# VBox(children=(Label(value='finance_statement (No table found)(對於finance_statement是正常情況)'), HBox(children=(Dat…
# start crawl price from  2008-02-01 to 2012-12-31
# HBox(children=(IntProgress(value=0, max=1796), HTML(value='')))
# crawling 2008-02-01
# success
# crawling 2008-02-02
# fail, check if it is a holiday
# crawling 2008-02-03
# fail, check if it is a holiday
# crawling 2008-02-04
# fail, check if it is a holiday
# crawling 2008-02-05
# fail, check if it is a holiday
# crawling 2008-02-06
# fail, check if it is a holiday
# crawling 2008-02-07
# fail, check if it is a holiday
# crawling 2008-02-08
# fail, check if it is a holiday
# crawling 2008-02-09
# fail, check if it is a holiday
# crawling 2008-02-10
# fail, check if it is a holiday
# crawling 2008-02-11
# fail, check if it is a holiday
# crawling 2008-02-12
# success
# crawling 2008-02-13
# success
# crawling 2008-02-14
# success
# crawling 2008-02-15
# success
# crawling 2008-02-16
# fail, check if it is a holiday
# crawling 2008-02-17
# fail, check if it is a holiday
# crawling 2008-02-18
# success
# crawling 2008-02-19
# success
# crawling 2008-02-20
# success
# crawling 2008-02-21
# success
# crawling 2008-02-22
# success
# crawling 2008-02-23
# fail, check if it is a holiday
# crawling 2008-02-24
# fail, check if it is a holiday
# crawling 2008-02-25
# success
# crawling 2008-02-26
# success
# crawling 2008-02-27
# success
# crawling 2008-02-28
# fail, check if it is a holiday
# crawling 2008-02-29
# success
# crawling 2008-03-01
# fail, check if it is a holiday
# crawling 2008-03-02
# fail, check if it is a holiday
# crawling 2008-03-03
# success
# crawling 2008-03-04
# success
# crawling 2008-03-05
# success
# crawling 2008-03-06
# success
# crawling 2008-03-07
# success
# crawling 2008-03-08
# fail, check if it is a holiday
# crawling 2008-03-09
# fail, check if it is a holiday
# crawling 2008-03-10
# success
# crawling 2008-03-11
# success
# crawling 2008-03-12
# success
# crawling 2008-03-13
# success
# crawling 2008-03-14
# success
# crawling 2008-03-15
# fail, check if it is a holiday
# crawling 2008-03-16
# fail, check if it is a holiday
# crawling 2008-03-17
# success
# crawling 2008-03-18
# success
# crawling 2008-03-19
# success
# crawling 2008-03-20
# success
# crawling 2008-03-21
# success
# crawling 2008-03-22
# fail, check if it is a holiday
# crawling 2008-03-23
# fail, check if it is a holiday
# crawling 2008-03-24
# success
# crawling 2008-03-25
# success
# crawling 2008-03-26
# success
# crawling 2008-03-27
# success
# crawling 2008-03-28
# success
# crawling 2008-03-29
# fail, check if it is a holiday
# crawling 2008-03-30
# fail, check if it is a holiday
# crawling 2008-03-31
# success
# crawling 2008-04-01
# success
# crawling 2008-04-02
# success
# crawling 2008-04-03
# success
# crawling 2008-04-04
# fail, check if it is a holiday
# crawling 2008-04-05
# fail, check if it is a holiday
# crawling 2008-04-06
# fail, check if it is a holiday
# crawling 2008-04-07
# success
# crawling 2008-04-08
# success
# crawling 2008-04-09
# success
# crawling 2008-04-10
# success
# crawling 2008-04-11
# success
# crawling 2008-04-12
# fail, check if it is a holiday
# crawling 2008-04-13
# fail, check if it is a holiday
# crawling 2008-04-14
# success
# crawling 2008-04-15
# success
# crawling 2008-04-16
# success
# crawling 2008-04-17
# success
# crawling 2008-04-18
# success
# crawling 2008-04-19
# fail, check if it is a holiday
# crawling 2008-04-20
# fail, check if it is a holiday
# crawling 2008-04-21
# success
# crawling 2008-04-22
# success
# crawling 2008-04-23
# success
# crawling 2008-04-24
# success
# crawling 2008-04-25
# success
# crawling 2008-04-26
# fail, check if it is a holiday
# crawling 2008-04-27
# fail, check if it is a holiday
# crawling 2008-04-28
# success
# crawling 2008-04-29
# success
# crawling 2008-04-30
# success
# crawling 2008-05-01
# fail, check if it is a holiday
# crawling 2008-05-02
# success
# crawling 2008-05-03
# fail, check if it is a holiday
# crawling 2008-05-04
# fail, check if it is a holiday
# crawling 2008-05-05
# success
# crawling 2008-05-06
# success
# crawling 2008-05-07
# success
# crawling 2008-05-08
# success
# crawling 2008-05-09
# success
# crawling 2008-05-10
# fail, check if it is a holiday
# crawling 2008-05-11
# fail, check if it is a holiday
# crawling 2008-05-12
# success
# crawling 2008-05-13
# success
# crawling 2008-05-14
# success
# crawling 2008-05-15
# success
# crawling 2008-05-16
# success
# crawling 2008-05-17
# fail, check if it is a holiday
# crawling 2008-05-18
# fail, check if it is a holiday
# crawling 2008-05-19
# success
# crawling 2008-05-20
# success
# crawling 2008-05-21
# success
# save 0
# crawling 2008-05-22
# success
# crawling 2008-05-23
# success
# crawling 2008-05-24
# fail, check if it is a holiday
# crawling 2008-05-25
# fail, check if it is a holiday
# crawling 2008-05-26
# success
# crawling 2008-05-27
# success
# crawling 2008-05-28
# success
# crawling 2008-05-29
# success
# crawling 2008-05-30
# success
# crawling 2008-05-31
# fail, check if it is a holiday
# crawling 2008-06-01
# fail, check if it is a holiday
# crawling 2008-06-02
# success
# crawling 2008-06-03
# success
# crawling 2008-06-04
# success
# crawling 2008-06-05
# success
# crawling 2008-06-06
# success
# crawling 2008-06-07
# fail, check if it is a holiday
# crawling 2008-06-08
# fail, check if it is a holiday
# crawling 2008-06-09
# success
# crawling 2008-06-10
# success
# crawling 2008-06-11
# success
# crawling 2008-06-12
# success
# crawling 2008-06-13
# success
# crawling 2008-06-14
# fail, check if it is a holiday
# crawling 2008-06-15
# fail, check if it is a holiday
# crawling 2008-06-16
# success
# crawling 2008-06-17
# success
# crawling 2008-06-18
# success
# crawling 2008-06-19
# success
# crawling 2008-06-20
# success
# crawling 2008-06-21
# fail, check if it is a holiday
# crawling 2008-06-22
# fail, check if it is a holiday
# crawling 2008-06-23
# success
# crawling 2008-06-24
# success
# crawling 2008-06-25
# success
# crawling 2008-06-26
# success
# crawling 2008-06-27
# success
# crawling 2008-06-28
# fail, check if it is a holiday
# crawling 2008-06-29
# fail, check if it is a holiday
# crawling 2008-06-30
# success
# crawling 2008-07-01
# success
# crawling 2008-07-02
# success
# crawling 2008-07-03
# success
# crawling 2008-07-04
# success
# crawling 2008-07-05
# fail, check if it is a holiday
# crawling 2008-07-06
# fail, check if it is a holiday
# crawling 2008-07-07
# success
# crawling 2008-07-08
# success
# crawling 2008-07-09
# success
# crawling 2008-07-10
# success
# crawling 2008-07-11
# success
# crawling 2008-07-12
# fail, check if it is a holiday
# crawling 2008-07-13
# fail, check if it is a holiday
# crawling 2008-07-14
# success
# crawling 2008-07-15
# success
# crawling 2008-07-16
# success
# crawling 2008-07-17
# success
# crawling 2008-07-18
# success
# crawling 2008-07-19
# fail, check if it is a holiday
# crawling 2008-07-20
# fail, check if it is a holiday
# crawling 2008-07-21
# success
# crawling 2008-07-22
# success
# crawling 2008-07-23
# success
# crawling 2008-07-24
# success
# crawling 2008-07-25
# success
# crawling 2008-07-26
# fail, check if it is a holiday
# crawling 2008-07-27
# fail, check if it is a holiday
# crawling 2008-07-28
# fail, check if it is a holiday
# crawling 2008-07-29
# success
# crawling 2008-07-30
# success
# crawling 2008-07-31
# success
# crawling 2008-08-01
# success
# crawling 2008-08-02
# fail, check if it is a holiday
# crawling 2008-08-03
# fail, check if it is a holiday
# crawling 2008-08-04
# success
# crawling 2008-08-05
# success
# crawling 2008-08-06
# success
# crawling 2008-08-07
# success
# crawling 2008-08-08
# success
# crawling 2008-08-09
# fail, check if it is a holiday
# crawling 2008-08-10
# fail, check if it is a holiday
# crawling 2008-08-11
# success
# crawling 2008-08-12
# success
# crawling 2008-08-13
# success
# crawling 2008-08-14
# success
# crawling 2008-08-15
# success
# crawling 2008-08-16
# fail, check if it is a holiday
# crawling 2008-08-17
# fail, check if it is a holiday
# crawling 2008-08-18
# success
# crawling 2008-08-19
# success
# crawling 2008-08-20
# success
# crawling 2008-08-21
# success
# crawling 2008-08-22
# success
# crawling 2008-08-23
# fail, check if it is a holiday
# crawling 2008-08-24
# fail, check if it is a holiday
# crawling 2008-08-25
# success
# crawling 2008-08-26
# success
# crawling 2008-08-27
# success
# crawling 2008-08-28
# success
# save 0
# crawling 2008-08-29
# success
# crawling 2008-08-30
# fail, check if it is a holiday
# crawling 2008-08-31
# fail, check if it is a holiday
# crawling 2008-09-01
# success
# crawling 2008-09-02
# success
# crawling 2008-09-03
# success
# crawling 2008-09-04
# success
# crawling 2008-09-05
# success
# crawling 2008-09-06
# fail, check if it is a holiday
# crawling 2008-09-07
# fail, check if it is a holiday
# crawling 2008-09-08
# success
# crawling 2008-09-09
# success
# crawling 2008-09-10
# success
# crawling 2008-09-11
# success
# crawling 2008-09-12
# success
# crawling 2008-09-13
# fail, check if it is a holiday
# crawling 2008-09-14
# fail, check if it is a holiday
# crawling 2008-09-15
# success
# crawling 2008-09-16
# success
# crawling 2008-09-17
# success
# crawling 2008-09-18
# success
# crawling 2008-09-19
# success
# crawling 2008-09-20
# fail, check if it is a holiday
# crawling 2008-09-21
# fail, check if it is a holiday
# crawling 2008-09-22
# success
# crawling 2008-09-23
# success
# crawling 2008-09-24
# success
# crawling 2008-09-25
# success
# crawling 2008-09-26
# success
# crawling 2008-09-27
# fail, check if it is a holiday
# crawling 2008-09-28
# fail, check if it is a holiday
# crawling 2008-09-29
# fail, check if it is a holiday
# crawling 2008-09-30
# success
# crawling 2008-10-01
# success
# crawling 2008-10-02
# success
# crawling 2008-10-03
# success
# crawling 2008-10-04
# fail, check if it is a holiday
# crawling 2008-10-05
# fail, check if it is a holiday
# crawling 2008-10-06
# success
# crawling 2008-10-07
# success
# crawling 2008-10-08
# success
# crawling 2008-10-09
# success
# crawling 2008-10-10
# fail, check if it is a holiday
# crawling 2008-10-11
# fail, check if it is a holiday
# crawling 2008-10-12
# fail, check if it is a holiday
# crawling 2008-10-13
# success
# crawling 2008-10-14
# success
# crawling 2008-10-15
# success
# crawling 2008-10-16
# success
# crawling 2008-10-17
# success
# crawling 2008-10-18
# fail, check if it is a holiday
# crawling 2008-10-19
# fail, check if it is a holiday
# crawling 2008-10-20
# success
# crawling 2008-10-21
# success
# crawling 2008-10-22
# success
# crawling 2008-10-23
# success
# crawling 2008-10-24
# success
# crawling 2008-10-25
# fail, check if it is a holiday
# crawling 2008-10-26
# fail, check if it is a holiday
# crawling 2008-10-27
# success
# crawling 2008-10-28
# success
# crawling 2008-10-29
# success
# crawling 2008-10-30
# success
# crawling 2008-10-31
# success
# crawling 2008-11-01
# fail, check if it is a holiday
# crawling 2008-11-02
# fail, check if it is a holiday
# crawling 2008-11-03
# success
# crawling 2008-11-04
# success
# crawling 2008-11-05
# success
# crawling 2008-11-06
# success
# crawling 2008-11-07
# success
# crawling 2008-11-08
# fail, check if it is a holiday
# crawling 2008-11-09
# fail, check if it is a holiday
# crawling 2008-11-10
# success
# crawling 2008-11-11
# success
# crawling 2008-11-12
# success
# crawling 2008-11-13
# success
# crawling 2008-11-14
# success
# crawling 2008-11-15
# fail, check if it is a holiday
# crawling 2008-11-16
# fail, check if it is a holiday
# crawling 2008-11-17
# success
# crawling 2008-11-18
# success
# crawling 2008-11-19
# success
# crawling 2008-11-20
# success
# crawling 2008-11-21
# success
# crawling 2008-11-22
# fail, check if it is a holiday
# crawling 2008-11-23
# fail, check if it is a holiday
# crawling 2008-11-24
# success
# crawling 2008-11-25
# success
# crawling 2008-11-26
# success
# crawling 2008-11-27
# success
# crawling 2008-11-28
# success
# crawling 2008-11-29
# fail, check if it is a holiday
# crawling 2008-11-30
# fail, check if it is a holiday
# crawling 2008-12-01
# success
# crawling 2008-12-02
# success
# crawling 2008-12-03
# success
# crawling 2008-12-04
# success
# crawling 2008-12-05
# success
# crawling 2008-12-06
# fail, check if it is a holiday
# crawling 2008-12-07
# fail, check if it is a holiday
# crawling 2008-12-08
# success
# save 0
# crawling 2008-12-09
# success
# crawling 2008-12-10
# success
# crawling 2008-12-11
# success
# crawling 2008-12-12
# success
# crawling 2008-12-13
# fail, check if it is a holiday
# crawling 2008-12-14
# fail, check if it is a holiday
# crawling 2008-12-15
# success
# crawling 2008-12-16
# success
# crawling 2008-12-17
# success
# crawling 2008-12-18
# success
# crawling 2008-12-19
# success
# crawling 2008-12-20
# fail, check if it is a holiday
# crawling 2008-12-21
# fail, check if it is a holiday
# crawling 2008-12-22
# success
# crawling 2008-12-23
# success
# crawling 2008-12-24
# success
# crawling 2008-12-25
# success
# crawling 2008-12-26
# success
# crawling 2008-12-27
# fail, check if it is a holiday
# crawling 2008-12-28
# fail, check if it is a holiday
# crawling 2008-12-29
# success
# crawling 2008-12-30
# success
# crawling 2008-12-31
# success
# crawling 2009-01-01
# fail, check if it is a holiday
# crawling 2009-01-02
# fail, check if it is a holiday
# crawling 2009-01-03
# fail, check if it is a holiday
# crawling 2009-01-04
# fail, check if it is a holiday
# crawling 2009-01-05
# success
# crawling 2009-01-06
# success
# crawling 2009-01-07
# success
# crawling 2009-01-08
# success
# crawling 2009-01-09
# success
# crawling 2009-01-10
# success
# crawling 2009-01-11
# fail, check if it is a holiday
# crawling 2009-01-12
# success
# crawling 2009-01-13
# success
# crawling 2009-01-14
# success
# crawling 2009-01-15
# success
# crawling 2009-01-16
# success
# crawling 2009-01-17
# success
# crawling 2009-01-18
# fail, check if it is a holiday
# crawling 2009-01-19
# success
# crawling 2009-01-20
# success
# crawling 2009-01-21
# success
# crawling 2009-01-22
# fail, check if it is a holiday
# crawling 2009-01-23
# fail, check if it is a holiday
# crawling 2009-01-24
# fail, check if it is a holiday
# crawling 2009-01-25
# fail, check if it is a holiday
# crawling 2009-01-26
# fail, check if it is a holiday
# crawling 2009-01-27
# fail, check if it is a holiday
# crawling 2009-01-28
# fail, check if it is a holiday
# crawling 2009-01-29
# fail, check if it is a holiday
# crawling 2009-01-30
# fail, check if it is a holiday
# crawling 2009-01-31
# fail, check if it is a holiday
# crawling 2009-02-01
# fail, check if it is a holiday
# crawling 2009-02-02
# success
# crawling 2009-02-03
# success
# crawling 2009-02-04
# success
# crawling 2009-02-05
# success
# crawling 2009-02-06
# success
# crawling 2009-02-07
# fail, check if it is a holiday
# crawling 2009-02-08
# fail, check if it is a holiday
# crawling 2009-02-09
# success
# crawling 2009-02-10
# success
# crawling 2009-02-11
# success
# crawling 2009-02-12
# success
# crawling 2009-02-13
# success
# crawling 2009-02-14
# fail, check if it is a holiday
# crawling 2009-02-15
# HTTPSConnectionPool(host='www.twse.com.tw', port=443): Max retries exceeded with url: /exchangeReport/MI_INDEX?response=csv&date=20090215&type=ALLBUT0999 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x000001BAC12F4A58>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# retry one more time after 60s 3 times left
# fail, check if it is a holiday
# crawling 2009-02-16
# success
# crawling 2009-02-17
# success
# crawling 2009-02-18
# success
# crawling 2009-02-19
# success
# crawling 2009-02-20
# success
# crawling 2009-02-21
# fail, check if it is a holiday
# crawling 2009-02-22
# fail, check if it is a holiday
# crawling 2009-02-23
# success
# crawling 2009-02-24
# success
# crawling 2009-02-25
# success
# crawling 2009-02-26
# success
# crawling 2009-02-27
# success
# crawling 2009-02-28
# fail, check if it is a holiday
# crawling 2009-03-01
# fail, check if it is a holiday
# crawling 2009-03-02
# success
# crawling 2009-03-03
# success
# crawling 2009-03-04
# success
# crawling 2009-03-05
# success
# crawling 2009-03-06
# success
# crawling 2009-03-07
# fail, check if it is a holiday
# crawling 2009-03-08
# fail, check if it is a holiday
# crawling 2009-03-09
# success
# crawling 2009-03-10
# success
# crawling 2009-03-11
# success
# crawling 2009-03-12
# success
# crawling 2009-03-13
# success
# crawling 2009-03-14
# fail, check if it is a holiday
# crawling 2009-03-15
# fail, check if it is a holiday
# crawling 2009-03-16
# success
# crawling 2009-03-17
# success
# crawling 2009-03-18
# success
# crawling 2009-03-19
# success
# crawling 2009-03-20
# success
# crawling 2009-03-21
# fail, check if it is a holiday
# crawling 2009-03-22
# fail, check if it is a holiday
# crawling 2009-03-23
# success
# crawling 2009-03-24
# success
# save 0
# crawling 2009-03-25
# success
# crawling 2009-03-26
# success
# crawling 2009-03-27
# success
# crawling 2009-03-28
# fail, check if it is a holiday
# crawling 2009-03-29
# fail, check if it is a holiday
# crawling 2009-03-30
# success
# crawling 2009-03-31
# success
# crawling 2009-04-01
# success
# crawling 2009-04-02
# success
# crawling 2009-04-03
# success
# crawling 2009-04-04
# fail, check if it is a holiday
# crawling 2009-04-05
# fail, check if it is a holiday
# crawling 2009-04-06
# success
# crawling 2009-04-07
# success
# crawling 2009-04-08
# success
# crawling 2009-04-09
# success
# crawling 2009-04-10
# success
# crawling 2009-04-11
# fail, check if it is a holiday
# crawling 2009-04-12
# fail, check if it is a holiday
# crawling 2009-04-13
# success
# crawling 2009-04-14
# success
# crawling 2009-04-15
# success
# crawling 2009-04-16
# success
# crawling 2009-04-17
# success
# crawling 2009-04-18
# fail, check if it is a holiday
# crawling 2009-04-19
# fail, check if it is a holiday
# crawling 2009-04-20
# success
# crawling 2009-04-21
# success
# crawling 2009-04-22
# success
# crawling 2009-04-23
# success
# crawling 2009-04-24
# success
# crawling 2009-04-25
# fail, check if it is a holiday
# crawling 2009-04-26
# fail, check if it is a holiday
# crawling 2009-04-27
# success
# crawling 2009-04-28
# success
# crawling 2009-04-29
# success
# crawling 2009-04-30
# success
# crawling 2009-05-01
# fail, check if it is a holiday
# crawling 2009-05-02
# fail, check if it is a holiday
# crawling 2009-05-03
# fail, check if it is a holiday
# crawling 2009-05-04
# success
# crawling 2009-05-05
# success
# crawling 2009-05-06
# success
# crawling 2009-05-07
# success
# crawling 2009-05-08
# success
# crawling 2009-05-09
# fail, check if it is a holiday
# crawling 2009-05-10
# fail, check if it is a holiday
# crawling 2009-05-11
# success
# crawling 2009-05-12
# success
# crawling 2009-05-13
# success
# crawling 2009-05-14
# success
# crawling 2009-05-15
# success
# crawling 2009-05-16
# fail, check if it is a holiday
# crawling 2009-05-17
# fail, check if it is a holiday
# crawling 2009-05-18
# success
# crawling 2009-05-19
# success
# crawling 2009-05-20
# success
# crawling 2009-05-21
# success
# crawling 2009-05-22
# success
# crawling 2009-05-23
# fail, check if it is a holiday
# crawling 2009-05-24
# fail, check if it is a holiday
# crawling 2009-05-25
# success
# crawling 2009-05-26
# success
# crawling 2009-05-27
# success
# crawling 2009-05-28
# fail, check if it is a holiday
# crawling 2009-05-29
# fail, check if it is a holiday
# crawling 2009-05-30
# fail, check if it is a holiday
# crawling 2009-05-31
# fail, check if it is a holiday
# crawling 2009-06-01
# success
# crawling 2009-06-02
# success
# crawling 2009-06-03
# success
# crawling 2009-06-04
# success
# crawling 2009-06-05
# success
# crawling 2009-06-06
# success
# crawling 2009-06-07
# fail, check if it is a holiday
# crawling 2009-06-08
# success
# crawling 2009-06-09
# success
# crawling 2009-06-10
# success
# crawling 2009-06-11
# success
# crawling 2009-06-12
# success
# crawling 2009-06-13
# fail, check if it is a holiday
# crawling 2009-06-14
# fail, check if it is a holiday
# crawling 2009-06-15
# success
# crawling 2009-06-16
# success
# crawling 2009-06-17
# success
# crawling 2009-06-18
# success
# crawling 2009-06-19
# success
# crawling 2009-06-20
# fail, check if it is a holiday
# crawling 2009-06-21
# fail, check if it is a holiday
# crawling 2009-06-22
# success
# crawling 2009-06-23
# success
# crawling 2009-06-24
# success
# crawling 2009-06-25
# success
# crawling 2009-06-26
# success
# crawling 2009-06-27
# fail, check if it is a holiday
# crawling 2009-06-28
# fail, check if it is a holiday
# crawling 2009-06-29
# success
# save 0
# crawling 2009-06-30
# success
# crawling 2009-07-01
# success
# crawling 2009-07-02
# success
# crawling 2009-07-03
# success
# crawling 2009-07-04
# fail, check if it is a holiday
# crawling 2009-07-05
# fail, check if it is a holiday
# crawling 2009-07-06
# success
# crawling 2009-07-07
# success
# crawling 2009-07-08
# success
# crawling 2009-07-09
# success
# crawling 2009-07-10
# success
# crawling 2009-07-11
# fail, check if it is a holiday
# crawling 2009-07-12
# fail, check if it is a holiday
# crawling 2009-07-13
# success
# crawling 2009-07-14
# success
# crawling 2009-07-15
# success
# crawling 2009-07-16
# success
# crawling 2009-07-17
# success
# crawling 2009-07-18
# fail, check if it is a holiday
# crawling 2009-07-19
# fail, check if it is a holiday
# crawling 2009-07-20
# success
# crawling 2009-07-21
# success
# crawling 2009-07-22
# success
# crawling 2009-07-23
# success
# crawling 2009-07-24
# success
# crawling 2009-07-25
# fail, check if it is a holiday
# crawling 2009-07-26
# fail, check if it is a holiday
# crawling 2009-07-27
# success
# crawling 2009-07-28
# success
# crawling 2009-07-29
# success
# crawling 2009-07-30
# success
# crawling 2009-07-31
# success
# crawling 2009-08-01
# fail, check if it is a holiday
# crawling 2009-08-02
# fail, check if it is a holiday
# crawling 2009-08-03
# success
# crawling 2009-08-04
# success
# crawling 2009-08-05
# success
# crawling 2009-08-06
# success
# crawling 2009-08-07
# fail, check if it is a holiday
# crawling 2009-08-08
# fail, check if it is a holiday
# crawling 2009-08-09
# fail, check if it is a holiday
# crawling 2009-08-10
# success
# crawling 2009-08-11
# success
# crawling 2009-08-12
# success
# crawling 2009-08-13
# success
# crawling 2009-08-14
# success
# crawling 2009-08-15
# fail, check if it is a holiday
# crawling 2009-08-16
# fail, check if it is a holiday
# crawling 2009-08-17
# success
# crawling 2009-08-18
# success
# crawling 2009-08-19
# success
# crawling 2009-08-20
# success
# crawling 2009-08-21
# success
# crawling 2009-08-22
# fail, check if it is a holiday
# crawling 2009-08-23
# fail, check if it is a holiday
# crawling 2009-08-24
# success
# crawling 2009-08-25
# success
# crawling 2009-08-26
# success
# crawling 2009-08-27
# success
# crawling 2009-08-28
# success
# crawling 2009-08-29
# fail, check if it is a holiday
# crawling 2009-08-30
# fail, check if it is a holiday
# crawling 2009-08-31
# success
# crawling 2009-09-01
# success
# crawling 2009-09-02
# success
# crawling 2009-09-03
# success
# crawling 2009-09-04
# success
# crawling 2009-09-05
# fail, check if it is a holiday
# crawling 2009-09-06
# fail, check if it is a holiday
# crawling 2009-09-07
# success
# crawling 2009-09-08
# success
# crawling 2009-09-09
# success
# crawling 2009-09-10
# success
# crawling 2009-09-11
# success
# crawling 2009-09-12
# fail, check if it is a holiday
# crawling 2009-09-13
# fail, check if it is a holiday
# crawling 2009-09-14
# success
# crawling 2009-09-15
# success
# crawling 2009-09-16
# success
# crawling 2009-09-17
# success
# crawling 2009-09-18
# success
# crawling 2009-09-19
# fail, check if it is a holiday
# crawling 2009-09-20
# fail, check if it is a holiday
# crawling 2009-09-21
# success
# crawling 2009-09-22
# success
# crawling 2009-09-23
# success
# crawling 2009-09-24
# success
# crawling 2009-09-25
# success
# crawling 2009-09-26
# fail, check if it is a holiday
# crawling 2009-09-27
# fail, check if it is a holiday
# crawling 2009-09-28
# success
# crawling 2009-09-29
# success
# crawling 2009-09-30
# success
# crawling 2009-10-01
# success
# save 0
# crawling 2009-10-02
# success
# crawling 2009-10-03
# fail, check if it is a holiday
# crawling 2009-10-04
# fail, check if it is a holiday
# crawling 2009-10-05
# success
# crawling 2009-10-06
# success
# crawling 2009-10-07
# success
# crawling 2009-10-08
# success
# crawling 2009-10-09
# success
# crawling 2009-10-10
# fail, check if it is a holiday
# crawling 2009-10-11
# fail, check if it is a holiday
# crawling 2009-10-12
# success
# crawling 2009-10-13
# success
# crawling 2009-10-14
# success
# crawling 2009-10-15
# success
# crawling 2009-10-16
# success
# crawling 2009-10-17
# fail, check if it is a holiday
# crawling 2009-10-18
# fail, check if it is a holiday
# crawling 2009-10-19
# success
# crawling 2009-10-20
# success
# crawling 2009-10-21
# success
# crawling 2009-10-22
# success
# crawling 2009-10-23
# success
# crawling 2009-10-24
# fail, check if it is a holiday
# crawling 2009-10-25
# fail, check if it is a holiday
# crawling 2009-10-26
# success
# crawling 2009-10-27
# success
# crawling 2009-10-28
# success
# crawling 2009-10-29
# success
# crawling 2009-10-30
# success
# crawling 2009-10-31
# fail, check if it is a holiday
# crawling 2009-11-01
# fail, check if it is a holiday
# crawling 2009-11-02
# success
# crawling 2009-11-03
# success
# crawling 2009-11-04
# success
# crawling 2009-11-05
# success
# crawling 2009-11-06
# success
# crawling 2009-11-07
# fail, check if it is a holiday
# crawling 2009-11-08
# fail, check if it is a holiday
# crawling 2009-11-09
# success
# crawling 2009-11-10
# success
# crawling 2009-11-11
# success
# crawling 2009-11-12
# success
# crawling 2009-11-13
# success
# crawling 2009-11-14
# fail, check if it is a holiday
# crawling 2009-11-15
# fail, check if it is a holiday
# crawling 2009-11-16
# success
# crawling 2009-11-17
# success
# crawling 2009-11-18
# success
# crawling 2009-11-19
# success
# crawling 2009-11-20
# success
# crawling 2009-11-21
# fail, check if it is a holiday
# crawling 2009-11-22
# fail, check if it is a holiday
# crawling 2009-11-23
# success
# crawling 2009-11-24
# success
# crawling 2009-11-25
# success
# crawling 2009-11-26
# success
# crawling 2009-11-27
# success
# crawling 2009-11-28
# fail, check if it is a holiday
# crawling 2009-11-29
# fail, check if it is a holiday
# crawling 2009-11-30
# success
# crawling 2009-12-01
# success
# crawling 2009-12-02
# success
# crawling 2009-12-03
# success
# crawling 2009-12-04
# success
# crawling 2009-12-05
# fail, check if it is a holiday
# crawling 2009-12-06
# fail, check if it is a holiday
# crawling 2009-12-07
# success
# crawling 2009-12-08
# success
# crawling 2009-12-09
# success
# crawling 2009-12-10
# success
# crawling 2009-12-11
# success
# crawling 2009-12-12
# fail, check if it is a holiday
# crawling 2009-12-13
# fail, check if it is a holiday
# crawling 2009-12-14
# success
# crawling 2009-12-15
# success
# crawling 2009-12-16
# success
# crawling 2009-12-17
# success
# crawling 2009-12-18
# success
# crawling 2009-12-19
# fail, check if it is a holiday
# crawling 2009-12-20
# fail, check if it is a holiday
# crawling 2009-12-21
# success
# crawling 2009-12-22
# success
# crawling 2009-12-23
# success
# crawling 2009-12-24
# success
# crawling 2009-12-25
# success
# crawling 2009-12-26
# fail, check if it is a holiday
# crawling 2009-12-27
# fail, check if it is a holiday
# crawling 2009-12-28
# success
# crawling 2009-12-29
# success
# crawling 2009-12-30
# success
# crawling 2009-12-31
# success
# crawling 2010-01-01
# fail, check if it is a holiday
# crawling 2010-01-02
# fail, check if it is a holiday
# crawling 2010-01-03
# fail, check if it is a holiday
# crawling 2010-01-04
# success
# save 0
# crawling 2010-01-05
# success
# crawling 2010-01-06
# success
# crawling 2010-01-07
# success
# crawling 2010-01-08
# success
# crawling 2010-01-09
# fail, check if it is a holiday
# crawling 2010-01-10
# fail, check if it is a holiday
# crawling 2010-01-11
# success
# crawling 2010-01-12
# success
# crawling 2010-01-13
# success
# crawling 2010-01-14
# success
# crawling 2010-01-15
# success
# crawling 2010-01-16
# fail, check if it is a holiday
# crawling 2010-01-17
# fail, check if it is a holiday
# crawling 2010-01-18
# success
# crawling 2010-01-19
# success
# crawling 2010-01-20
# success
# crawling 2010-01-21
# success
# crawling 2010-01-22
# success
# crawling 2010-01-23
# fail, check if it is a holiday
# crawling 2010-01-24
# fail, check if it is a holiday
# crawling 2010-01-25
# success
# crawling 2010-01-26
# success
# crawling 2010-01-27
# success
# crawling 2010-01-28
# success
# crawling 2010-01-29
# success
# crawling 2010-01-30
# fail, check if it is a holiday
# crawling 2010-01-31
# fail, check if it is a holiday
# crawling 2010-02-01
# success
# crawling 2010-02-02
# success
# crawling 2010-02-03
# success
# crawling 2010-02-04
# success
# crawling 2010-02-05
# success
# crawling 2010-02-06
# success
# crawling 2010-02-07
# fail, check if it is a holiday
# crawling 2010-02-08
# success
# crawling 2010-02-09
# success
# crawling 2010-02-10
# success
# crawling 2010-02-11
# fail, check if it is a holiday
# crawling 2010-02-12
# fail, check if it is a holiday
# crawling 2010-02-13
# fail, check if it is a holiday
# crawling 2010-02-14
# fail, check if it is a holiday
# crawling 2010-02-15
# fail, check if it is a holiday
# crawling 2010-02-16
# fail, check if it is a holiday
# crawling 2010-02-17
# fail, check if it is a holiday
# crawling 2010-02-18
# fail, check if it is a holiday
# crawling 2010-02-19
# fail, check if it is a holiday
# crawling 2010-02-20
# fail, check if it is a holiday
# crawling 2010-02-21
# fail, check if it is a holiday
# crawling 2010-02-22
# success
# crawling 2010-02-23
# success
# crawling 2010-02-24
# success
# crawling 2010-02-25
# success
# crawling 2010-02-26
# success
# crawling 2010-02-27
# fail, check if it is a holiday
# crawling 2010-02-28
# fail, check if it is a holiday
# crawling 2010-03-01
# success
# crawling 2010-03-02
# success
# crawling 2010-03-03
# success
# crawling 2010-03-04
# success
# crawling 2010-03-05
# success
# crawling 2010-03-06
# fail, check if it is a holiday
# crawling 2010-03-07
# fail, check if it is a holiday
# crawling 2010-03-08
# success
# crawling 2010-03-09
# success
# crawling 2010-03-10
# success
# crawling 2010-03-11
# success
# crawling 2010-03-12
# success
# crawling 2010-03-13
# fail, check if it is a holiday
# crawling 2010-03-14
# fail, check if it is a holiday
# crawling 2010-03-15
# success
# crawling 2010-03-16
# success
# crawling 2010-03-17
# success
# crawling 2010-03-18
# success
# crawling 2010-03-19
# success
# crawling 2010-03-20
# fail, check if it is a holiday
# crawling 2010-03-21
# fail, check if it is a holiday
# crawling 2010-03-22
# success
# crawling 2010-03-23
# success
# crawling 2010-03-24
# success
# crawling 2010-03-25
# success
# crawling 2010-03-26
# success
# crawling 2010-03-27
# fail, check if it is a holiday
# crawling 2010-03-28
# fail, check if it is a holiday
# crawling 2010-03-29
# success
# crawling 2010-03-30
# success
# crawling 2010-03-31
# success
# crawling 2010-04-01
# success
# crawling 2010-04-02
# success
# crawling 2010-04-03
# fail, check if it is a holiday
# crawling 2010-04-04
# fail, check if it is a holiday
# crawling 2010-04-05
# fail, check if it is a holiday
# crawling 2010-04-06
# success
# crawling 2010-04-07
# success
# crawling 2010-04-08
# success
# crawling 2010-04-09
# success
# crawling 2010-04-10
# fail, check if it is a holiday
# crawling 2010-04-11
# fail, check if it is a holiday
# crawling 2010-04-12
# success
# crawling 2010-04-13
# success
# crawling 2010-04-14
# success
# save 0
# crawling 2010-04-15
# success
# crawling 2010-04-16
# success
# crawling 2010-04-17
# fail, check if it is a holiday
# crawling 2010-04-18
# fail, check if it is a holiday
# crawling 2010-04-19
# success
# crawling 2010-04-20
# success
# crawling 2010-04-21
# success
# crawling 2010-04-22
# success
# crawling 2010-04-23
# success
# crawling 2010-04-24
# fail, check if it is a holiday
# crawling 2010-04-25
# fail, check if it is a holiday
# crawling 2010-04-26
# success
# crawling 2010-04-27
# success
# crawling 2010-04-28
# success
# crawling 2010-04-29
# success
# crawling 2010-04-30
# success
# crawling 2010-05-01
# fail, check if it is a holiday
# crawling 2010-05-02
# fail, check if it is a holiday
# crawling 2010-05-03
# success
# crawling 2010-05-04
# success
# crawling 2010-05-05
# success
# crawling 2010-05-06
# success
# crawling 2010-05-07
# success
# crawling 2010-05-08
# fail, check if it is a holiday
# crawling 2010-05-09
# fail, check if it is a holiday
# crawling 2010-05-10
# success
# crawling 2010-05-11
# success
# crawling 2010-05-12
# success
# crawling 2010-05-13
# success
# crawling 2010-05-14
# success
# crawling 2010-05-15
# fail, check if it is a holiday
# crawling 2010-05-16
# fail, check if it is a holiday
# crawling 2010-05-17
# success
# crawling 2010-05-18
# success
# crawling 2010-05-19
# success
# crawling 2010-05-20
# success
# crawling 2010-05-21
# success
# crawling 2010-05-22
# fail, check if it is a holiday
# crawling 2010-05-23
# fail, check if it is a holiday
# crawling 2010-05-24
# success
# crawling 2010-05-25
# success
# crawling 2010-05-26
# success
# crawling 2010-05-27
# success
# crawling 2010-05-28
# success
# crawling 2010-05-29
# fail, check if it is a holiday
# crawling 2010-05-30
# fail, check if it is a holiday
# crawling 2010-05-31
# success
# crawling 2010-06-01
# success
# crawling 2010-06-02
# success
# crawling 2010-06-03
# success
# crawling 2010-06-04
# success
# crawling 2010-06-05
# fail, check if it is a holiday
# crawling 2010-06-06
# fail, check if it is a holiday
# crawling 2010-06-07
# success
# crawling 2010-06-08
# success
# crawling 2010-06-09
# success
# crawling 2010-06-10
# success
# crawling 2010-06-11
# success
# crawling 2010-06-12
# fail, check if it is a holiday
# crawling 2010-06-13
# fail, check if it is a holiday
# crawling 2010-06-14
# success
# crawling 2010-06-15
# success
# crawling 2010-06-16
# fail, check if it is a holiday
# crawling 2010-06-17
# success
# crawling 2010-06-18
# success
# crawling 2010-06-19
# fail, check if it is a holiday
# crawling 2010-06-20
# fail, check if it is a holiday
# crawling 2010-06-21
# success
# crawling 2010-06-22
# success
# crawling 2010-06-23
# success
# crawling 2010-06-24
# success
# crawling 2010-06-25
# success
# crawling 2010-06-26
# fail, check if it is a holiday
# crawling 2010-06-27
# fail, check if it is a holiday
# crawling 2010-06-28
# success
# crawling 2010-06-29
# success
# crawling 2010-06-30
# success
# crawling 2010-07-01
# success
# crawling 2010-07-02
# success
# crawling 2010-07-03
# fail, check if it is a holiday
# crawling 2010-07-04
# fail, check if it is a holiday
# crawling 2010-07-05
# success
# crawling 2010-07-06
# success
# crawling 2010-07-07
# success
# crawling 2010-07-08
# success
# crawling 2010-07-09
# success
# crawling 2010-07-10
# fail, check if it is a holiday
# crawling 2010-07-11
# fail, check if it is a holiday
# crawling 2010-07-12
# success
# crawling 2010-07-13
# success
# crawling 2010-07-14
# success
# crawling 2010-07-15
# success
# save 0
# crawling 2010-07-16
# success
# crawling 2010-07-17
# fail, check if it is a holiday
# crawling 2010-07-18
# fail, check if it is a holiday
# crawling 2010-07-19
# success
# crawling 2010-07-20
# success
# crawling 2010-07-21
# success
# crawling 2010-07-22
# success
# crawling 2010-07-23
# success
# crawling 2010-07-24
# fail, check if it is a holiday
# crawling 2010-07-25
# fail, check if it is a holiday
# crawling 2010-07-26
# success
# crawling 2010-07-27
# success
# crawling 2010-07-28
# success
# crawling 2010-07-29
# success
# crawling 2010-07-30
# success
# crawling 2010-07-31
# fail, check if it is a holiday
# crawling 2010-08-01
# fail, check if it is a holiday
# crawling 2010-08-02
# success
# crawling 2010-08-03
# success
# crawling 2010-08-04
# success
# crawling 2010-08-05
# success
# crawling 2010-08-06
# success
# crawling 2010-08-07
# fail, check if it is a holiday
# crawling 2010-08-08
# fail, check if it is a holiday
# crawling 2010-08-09
# success
# crawling 2010-08-10
# success
# crawling 2010-08-11
# success
# crawling 2010-08-12
# success
# crawling 2010-08-13
# success
# crawling 2010-08-14
# fail, check if it is a holiday
# crawling 2010-08-15
# fail, check if it is a holiday
# crawling 2010-08-16
# success
# crawling 2010-08-17
# success
# crawling 2010-08-18
# success
# crawling 2010-08-19
# success
# crawling 2010-08-20
# success
# crawling 2010-08-21
# fail, check if it is a holiday
# crawling 2010-08-22
# fail, check if it is a holiday
# crawling 2010-08-23
# success
# crawling 2010-08-24
# success
# crawling 2010-08-25
# success
# crawling 2010-08-26
# success
# crawling 2010-08-27
# success
# crawling 2010-08-28
# fail, check if it is a holiday
# crawling 2010-08-29
# fail, check if it is a holiday
# crawling 2010-08-30
# success
# crawling 2010-08-31
# success
# crawling 2010-09-01
# success
# crawling 2010-09-02
# success
# crawling 2010-09-03
# success
# crawling 2010-09-04
# fail, check if it is a holiday
# crawling 2010-09-05
# fail, check if it is a holiday
# crawling 2010-09-06
# success
# crawling 2010-09-07
# success
# crawling 2010-09-08
# success
# crawling 2010-09-09
# success
# crawling 2010-09-10
# success
# crawling 2010-09-11
# fail, check if it is a holiday
# crawling 2010-09-12
# fail, check if it is a holiday
# crawling 2010-09-13
# success
# crawling 2010-09-14
# success
# crawling 2010-09-15
# success
# crawling 2010-09-16
# success
# crawling 2010-09-17
# success
# crawling 2010-09-18
# fail, check if it is a holiday
# crawling 2010-09-19
# fail, check if it is a holiday
# crawling 2010-09-20
# success
# crawling 2010-09-21
# success
# crawling 2010-09-22
# fail, check if it is a holiday
# crawling 2010-09-23
# success
# crawling 2010-09-24
# success
# crawling 2010-09-25
# fail, check if it is a holiday
# crawling 2010-09-26
# fail, check if it is a holiday
# crawling 2010-09-27
# success
# crawling 2010-09-28
# success
# crawling 2010-09-29
# success
# crawling 2010-09-30
# success
# crawling 2010-10-01
# success
# crawling 2010-10-02
# fail, check if it is a holiday
# crawling 2010-10-03
# fail, check if it is a holiday
# crawling 2010-10-04
# success
# crawling 2010-10-05
# success
# crawling 2010-10-06
# success
# crawling 2010-10-07
# success
# crawling 2010-10-08
# success
# crawling 2010-10-09
# fail, check if it is a holiday
# crawling 2010-10-10
# fail, check if it is a holiday
# crawling 2010-10-11
# success
# crawling 2010-10-12
# success
# crawling 2010-10-13
# success
# crawling 2010-10-14
# success
# crawling 2010-10-15
# success
# save 0
# crawling 2010-10-16
# fail, check if it is a holiday
# crawling 2010-10-17
# fail, check if it is a holiday
# crawling 2010-10-18
# success
# crawling 2010-10-19
# success
# crawling 2010-10-20
# success
# crawling 2010-10-21
# success
# crawling 2010-10-22
# success
# crawling 2010-10-23
# fail, check if it is a holiday
# crawling 2010-10-24
# fail, check if it is a holiday
# crawling 2010-10-25
# success
# crawling 2010-10-26
# success
# crawling 2010-10-27
# success
# crawling 2010-10-28
# success
# crawling 2010-10-29
# success
# crawling 2010-10-30
# fail, check if it is a holiday
# crawling 2010-10-31
# fail, check if it is a holiday
# crawling 2010-11-01
# success
# crawling 2010-11-02
# success
# crawling 2010-11-03
# success
# crawling 2010-11-04
# success
# crawling 2010-11-05
# success
# crawling 2010-11-06
# fail, check if it is a holiday
# crawling 2010-11-07
# fail, check if it is a holiday
# crawling 2010-11-08
# success
# crawling 2010-11-09
# success
# crawling 2010-11-10
# success
# crawling 2010-11-11
# success
# crawling 2010-11-12
# success
# crawling 2010-11-13
# fail, check if it is a holiday
# crawling 2010-11-14
# fail, check if it is a holiday
# crawling 2010-11-15
# success
# crawling 2010-11-16
# success
# crawling 2010-11-17
# success
# crawling 2010-11-18
# success
# crawling 2010-11-19
# success
# crawling 2010-11-20
# fail, check if it is a holiday
# crawling 2010-11-21
# fail, check if it is a holiday
# crawling 2010-11-22
# success
# crawling 2010-11-23
# success
# crawling 2010-11-24
# success
# crawling 2010-11-25
# success
# crawling 2010-11-26
# success
# crawling 2010-11-27
# fail, check if it is a holiday
# crawling 2010-11-28
# fail, check if it is a holiday
# crawling 2010-11-29
# success
# crawling 2010-11-30
# success
# crawling 2010-12-01
# success
# crawling 2010-12-02
# success
# crawling 2010-12-03
# success
# crawling 2010-12-04
# fail, check if it is a holiday
# crawling 2010-12-05
# fail, check if it is a holiday
# crawling 2010-12-06
# success
# crawling 2010-12-07
# success
# crawling 2010-12-08
# success
# crawling 2010-12-09
# success
# crawling 2010-12-10
# success
# crawling 2010-12-11
# fail, check if it is a holiday
# crawling 2010-12-12
# fail, check if it is a holiday
# crawling 2010-12-13
# success
# crawling 2010-12-14
# success
# crawling 2010-12-15
# success
# crawling 2010-12-16
# success
# crawling 2010-12-17
# success
# crawling 2010-12-18
# fail, check if it is a holiday
# crawling 2010-12-19
# fail, check if it is a holiday
# crawling 2010-12-20
# success
# crawling 2010-12-21
# success
# crawling 2010-12-22
# success
# crawling 2010-12-23
# success
# crawling 2010-12-24
# success
# crawling 2010-12-25
# fail, check if it is a holiday
# crawling 2010-12-26
# fail, check if it is a holiday
# crawling 2010-12-27
# success
# crawling 2010-12-28
# success
# crawling 2010-12-29
# success
# crawling 2010-12-30
# success
# crawling 2010-12-31
# success
# crawling 2011-01-01
# fail, check if it is a holiday
# crawling 2011-01-02
# fail, check if it is a holiday
# crawling 2011-01-03
# success
# crawling 2011-01-04
# success
# crawling 2011-01-05
# success
# crawling 2011-01-06
# success
# crawling 2011-01-07
# success
# crawling 2011-01-08
# fail, check if it is a holiday
# crawling 2011-01-09
# fail, check if it is a holiday
# crawling 2011-01-10
# success
# crawling 2011-01-11
# success
# crawling 2011-01-12
# success
# save 0
# crawling 2011-01-13
# success
# crawling 2011-01-14
# success
# crawling 2011-01-15
# fail, check if it is a holiday
# crawling 2011-01-16
# fail, check if it is a holiday
# crawling 2011-01-17
# success
# crawling 2011-01-18
# success
# crawling 2011-01-19
# success
# crawling 2011-01-20
# success
# crawling 2011-01-21
# success
# crawling 2011-01-22
# fail, check if it is a holiday
# crawling 2011-01-23
# fail, check if it is a holiday
# crawling 2011-01-24
# success
# crawling 2011-01-25
# success
# crawling 2011-01-26
# success
# crawling 2011-01-27
# success
# crawling 2011-01-28
# success
# crawling 2011-01-29
# fail, check if it is a holiday
# crawling 2011-01-30
# fail, check if it is a holiday
# crawling 2011-01-31
# fail, check if it is a holiday
# crawling 2011-02-01
# fail, check if it is a holiday
# crawling 2011-02-02
# fail, check if it is a holiday
# crawling 2011-02-03
# fail, check if it is a holiday
# crawling 2011-02-04
# fail, check if it is a holiday
# crawling 2011-02-05
# fail, check if it is a holiday
# crawling 2011-02-06
# fail, check if it is a holiday
# crawling 2011-02-07
# fail, check if it is a holiday
# crawling 2011-02-08
# success
# crawling 2011-02-09
# success
# crawling 2011-02-10
# success
# crawling 2011-02-11
# success
# crawling 2011-02-12
# fail, check if it is a holiday
# crawling 2011-02-13
# fail, check if it is a holiday
# crawling 2011-02-14
# success
# crawling 2011-02-15
# success
# crawling 2011-02-16
# success
# crawling 2011-02-17
# success
# crawling 2011-02-18
# success
# crawling 2011-02-19
# fail, check if it is a holiday
# crawling 2011-02-20
# fail, check if it is a holiday
# crawling 2011-02-21
# success
# crawling 2011-02-22
# success
# crawling 2011-02-23
# success
# crawling 2011-02-24
# success
# crawling 2011-02-25
# success
# crawling 2011-02-26
# fail, check if it is a holiday
# crawling 2011-02-27
# fail, check if it is a holiday
# crawling 2011-02-28
# fail, check if it is a holiday
# crawling 2011-03-01
# success
# crawling 2011-03-02
# success
# crawling 2011-03-03
# success
# crawling 2011-03-04
# success
# crawling 2011-03-05
# fail, check if it is a holiday
# crawling 2011-03-06
# fail, check if it is a holiday
# crawling 2011-03-07
# success
# crawling 2011-03-08
# success
# crawling 2011-03-09
# success
# crawling 2011-03-10
# success
# crawling 2011-03-11
# success
# crawling 2011-03-12
# fail, check if it is a holiday
# crawling 2011-03-13
# fail, check if it is a holiday
# crawling 2011-03-14
# success
# crawling 2011-03-15
# success
# crawling 2011-03-16
# success
# crawling 2011-03-17
# success
# crawling 2011-03-18
# success
# crawling 2011-03-19
# fail, check if it is a holiday
# crawling 2011-03-20
# fail, check if it is a holiday
# crawling 2011-03-21
# success
# crawling 2011-03-22
# success
# crawling 2011-03-23
# success
# crawling 2011-03-24
# success
# crawling 2011-03-25
# success
# crawling 2011-03-26
# fail, check if it is a holiday
# crawling 2011-03-27
# fail, check if it is a holiday
# crawling 2011-03-28
# success
# crawling 2011-03-29
# success
# crawling 2011-03-30
# success
# crawling 2011-03-31
# success
# crawling 2011-04-01
# success
# crawling 2011-04-02
# fail, check if it is a holiday
# crawling 2011-04-03
# fail, check if it is a holiday
# crawling 2011-04-04
# fail, check if it is a holiday
# crawling 2011-04-05
# fail, check if it is a holiday
# crawling 2011-04-06
# success
# crawling 2011-04-07
# success
# crawling 2011-04-08
# success
# crawling 2011-04-09
# fail, check if it is a holiday
# crawling 2011-04-10
# fail, check if it is a holiday
# crawling 2011-04-11
# success
# crawling 2011-04-12
# success
# crawling 2011-04-13
# success
# crawling 2011-04-14
# success
# crawling 2011-04-15
# success
# crawling 2011-04-16
# fail, check if it is a holiday
# crawling 2011-04-17
# fail, check if it is a holiday
# crawling 2011-04-18
# success
# crawling 2011-04-19
# success
# crawling 2011-04-20
# success
# crawling 2011-04-21
# success
# save 0
# crawling 2011-04-22
# success
# crawling 2011-04-23
# fail, check if it is a holiday
# crawling 2011-04-24
# fail, check if it is a holiday
# crawling 2011-04-25
# success
# crawling 2011-04-26
# success
# crawling 2011-04-27
# success
# crawling 2011-04-28
# success
# crawling 2011-04-29
# success
# crawling 2011-04-30
# fail, check if it is a holiday
# crawling 2011-05-01
# fail, check if it is a holiday
# crawling 2011-05-02
# fail, check if it is a holiday
# crawling 2011-05-03
# success
# crawling 2011-05-04
# success
# crawling 2011-05-05
# success
# crawling 2011-05-06
# success
# crawling 2011-05-07
# fail, check if it is a holiday
# crawling 2011-05-08
# fail, check if it is a holiday
# crawling 2011-05-09
# success
# crawling 2011-05-10
# success
# crawling 2011-05-11
# success
# crawling 2011-05-12
# success
# crawling 2011-05-13
# success
# crawling 2011-05-14
# fail, check if it is a holiday
# crawling 2011-05-15
# fail, check if it is a holiday
# crawling 2011-05-16
# success
# crawling 2011-05-17
# success
# crawling 2011-05-18
# success
# crawling 2011-05-19
# success
# crawling 2011-05-20
# success
# crawling 2011-05-21
# fail, check if it is a holiday
# crawling 2011-05-22
# fail, check if it is a holiday
# crawling 2011-05-23
# success
# crawling 2011-05-24
# success
# crawling 2011-05-25
# success
# crawling 2011-05-26
# success
# crawling 2011-05-27
# success
# crawling 2011-05-28
# fail, check if it is a holiday
# crawling 2011-05-29
# fail, check if it is a holiday
# crawling 2011-05-30
# success
# crawling 2011-05-31
# success
# crawling 2011-06-01
# success
# crawling 2011-06-02
# success
# crawling 2011-06-03
# success
# crawling 2011-06-04
# fail, check if it is a holiday
# crawling 2011-06-05
# fail, check if it is a holiday
# crawling 2011-06-06
# fail, check if it is a holiday
# crawling 2011-06-07
# success
# crawling 2011-06-08
# success
# crawling 2011-06-09
# success
# crawling 2011-06-10
# success
# crawling 2011-06-11
# fail, check if it is a holiday
# crawling 2011-06-12
# fail, check if it is a holiday
# crawling 2011-06-13
# success
# crawling 2011-06-14
# success
# crawling 2011-06-15
# success
# crawling 2011-06-16
# success
# crawling 2011-06-17
# success
# crawling 2011-06-18
# fail, check if it is a holiday
# crawling 2011-06-19
# fail, check if it is a holiday
# crawling 2011-06-20
# success
# crawling 2011-06-21
# success
# crawling 2011-06-22
# success
# crawling 2011-06-23
# success
# crawling 2011-06-24
# success
# crawling 2011-06-25
# fail, check if it is a holiday
# crawling 2011-06-26
# fail, check if it is a holiday
# crawling 2011-06-27
# success
# crawling 2011-06-28
# success
# crawling 2011-06-29
# success
# crawling 2011-06-30
# success
# crawling 2011-07-01
# success
# crawling 2011-07-02
# fail, check if it is a holiday
# crawling 2011-07-03
# fail, check if it is a holiday
# crawling 2011-07-04
# success
# crawling 2011-07-05
# success
# crawling 2011-07-06
# success
# crawling 2011-07-07
# success
# crawling 2011-07-08
# success
# crawling 2011-07-09
# fail, check if it is a holiday
# crawling 2011-07-10
# fail, check if it is a holiday
# crawling 2011-07-11
# success
# crawling 2011-07-12
# success
# crawling 2011-07-13
# success
# crawling 2011-07-14
# success
# crawling 2011-07-15
# success
# crawling 2011-07-16
# fail, check if it is a holiday
# crawling 2011-07-17
# fail, check if it is a holiday
# crawling 2011-07-18
# success
# crawling 2011-07-19
# success
# crawling 2011-07-20
# success
# save 0
# crawling 2011-07-21
# success
# crawling 2011-07-22
# success
# crawling 2011-07-23
# fail, check if it is a holiday
# crawling 2011-07-24
# fail, check if it is a holiday
# crawling 2011-07-25
# success
# crawling 2011-07-26
# success
# crawling 2011-07-27
# success
# crawling 2011-07-28
# success
# crawling 2011-07-29
# success
# crawling 2011-07-30
# fail, check if it is a holiday
# crawling 2011-07-31
# fail, check if it is a holiday
# crawling 2011-08-01
# success
# crawling 2011-08-02
# success
# crawling 2011-08-03
# success
# crawling 2011-08-04
# success
# crawling 2011-08-05
# success
# crawling 2011-08-06
# fail, check if it is a holiday
# crawling 2011-08-07
# fail, check if it is a holiday
# crawling 2011-08-08
# success
# crawling 2011-08-09
# success
# crawling 2011-08-10
# success
# crawling 2011-08-11
# success
# crawling 2011-08-12
# success
# crawling 2011-08-13
# fail, check if it is a holiday
# crawling 2011-08-14
# fail, check if it is a holiday
# crawling 2011-08-15
# success
# crawling 2011-08-16
# success
# crawling 2011-08-17
# success
# crawling 2011-08-18
# success
# crawling 2011-08-19
# success
# crawling 2011-08-20
# fail, check if it is a holiday
# crawling 2011-08-21
# fail, check if it is a holiday
# crawling 2011-08-22
# success
# crawling 2011-08-23
# success
# crawling 2011-08-24
# success
# crawling 2011-08-25
# success
# crawling 2011-08-26
# success
# crawling 2011-08-27
# fail, check if it is a holiday
# crawling 2011-08-28
# fail, check if it is a holiday
# crawling 2011-08-29
# success
# crawling 2011-08-30
# success
# crawling 2011-08-31
# success
# crawling 2011-09-01
# success
# crawling 2011-09-02
# success
# crawling 2011-09-03
# fail, check if it is a holiday
# crawling 2011-09-04
# fail, check if it is a holiday
# crawling 2011-09-05
# success
# crawling 2011-09-06
# success
# crawling 2011-09-07
# success
# crawling 2011-09-08
# success
# crawling 2011-09-09
# success
# crawling 2011-09-10
# fail, check if it is a holiday
# crawling 2011-09-11
# fail, check if it is a holiday
# crawling 2011-09-12
# fail, check if it is a holiday
# crawling 2011-09-13
# success
# crawling 2011-09-14
# success
# crawling 2011-09-15
# success
# crawling 2011-09-16
# success
# crawling 2011-09-17
# fail, check if it is a holiday
# crawling 2011-09-18
# fail, check if it is a holiday
# crawling 2011-09-19
# success
# crawling 2011-09-20
# success
# crawling 2011-09-21
# success
# crawling 2011-09-22
# success
# crawling 2011-09-23
# success
# crawling 2011-09-24
# fail, check if it is a holiday
# ...
# success
# crawling 2011-10-06
# success
# crawling 2011-10-07
# success
# crawling 2011-10-08
# fail, check if it is a holiday
# crawling 2011-10-09
# fail, check if it is a holiday
# crawling 2011-10-10
# fail, check if it is a holiday
# crawling 2011-10-11
# success
# crawling 2011-10-12
# success
# crawling 2011-10-13
# success
# crawling 2011-10-14
# success
# crawling 2011-10-15
# fail, check if it is a holiday
# crawling 2011-10-16
# fail, check if it is a holiday
# crawling 2011-10-17
# success
# save 0
# crawling 2011-10-18
# success
# crawling 2011-10-19
# success
# crawling 2011-10-20
# success
# crawling 2011-10-21
# success
# crawling 2011-10-22
# fail, check if it is a holiday
# crawling 2011-10-23
# fail, check if it is a holiday
# crawling 2011-10-24
# success
# crawling 2011-10-25
# success
# crawling 2011-10-26
# success
# crawling 2011-10-27
# success
# crawling 2011-10-28
# success
# crawling 2011-10-29
# fail, check if it is a holiday
# crawling 2011-10-30
# fail, check if it is a holiday
# crawling 2011-10-31
# success
# crawling 2011-11-01
# success
# crawling 2011-11-02
# success
# crawling 2011-11-03
# success
# crawling 2011-11-04
# success
# crawling 2011-11-05
# fail, check if it is a holiday
# crawling 2011-11-06
# fail, check if it is a holiday
# crawling 2011-11-07
# success
# crawling 2011-11-08
# success
# crawling 2011-11-09
# success
# crawling 2011-11-10
# success
# crawling 2011-11-11
# success
# crawling 2011-11-12
# fail, check if it is a holiday
# crawling 2011-11-13
# fail, check if it is a holiday
# crawling 2011-11-14
# success
# crawling 2011-11-15
# success
# crawling 2011-11-16
# success
# crawling 2011-11-17
# success
# crawling 2011-11-18
# success
# crawling 2011-11-19
# fail, check if it is a holiday
# crawling 2011-11-20
# fail, check if it is a holiday
# crawling 2011-11-21
# success
# crawling 2011-11-22
# success
# crawling 2011-11-23
# success
# crawling 2011-11-24
# success
# crawling 2011-11-25
# success
# crawling 2011-11-26
# fail, check if it is a holiday
# crawling 2011-11-27
# fail, check if it is a holiday
# crawling 2011-11-28
# success
# crawling 2011-11-29
# success
# crawling 2011-11-30
# success
# crawling 2011-12-01
# success
# crawling 2011-12-02
# success
# crawling 2011-12-03
# fail, check if it is a holiday
# crawling 2011-12-04
# fail, check if it is a holiday
# crawling 2011-12-05
# success
# crawling 2011-12-06
# success
# crawling 2011-12-07
# success
# crawling 2011-12-08
# success
# crawling 2011-12-09
# success
# crawling 2011-12-10
# fail, check if it is a holiday
# crawling 2011-12-11
# fail, check if it is a holiday
# crawling 2011-12-12
# success
# crawling 2011-12-13
# success
# crawling 2011-12-14
# success
# crawling 2011-12-15
# success
# crawling 2011-12-16
# success
# crawling 2011-12-17
# fail, check if it is a holiday
# crawling 2011-12-18
# fail, check if it is a holiday
# crawling 2011-12-19
# success
# crawling 2011-12-20
# success
# crawling 2011-12-21
# success
# crawling 2011-12-22
# success
# crawling 2011-12-23
# success
# crawling 2011-12-24
# fail, check if it is a holiday
# crawling 2011-12-25
# fail, check if it is a holiday
# crawling 2011-12-26
# success
# crawling 2011-12-27
# success
# crawling 2011-12-28
# success
# crawling 2011-12-29
# success
# crawling 2011-12-30
# success
# crawling 2011-12-31
# fail, check if it is a holiday
# crawling 2012-01-01
# fail, check if it is a holiday
# crawling 2012-01-02
# success
# crawling 2012-01-03
# success
# crawling 2012-01-04
# success
# crawling 2012-01-05
# success
# crawling 2012-01-06
# success
# crawling 2012-01-07
# fail, check if it is a holiday
# crawling 2012-01-08
# fail, check if it is a holiday
# crawling 2012-01-09
# success
# save 0
# crawling 2012-01-10
# success
# crawling 2012-01-11
# success
# crawling 2012-01-12
# success
# crawling 2012-01-13
# success
# crawling 2012-01-14
# fail, check if it is a holiday
# crawling 2012-01-15
# fail, check if it is a holiday
# crawling 2012-01-16
# success
# crawling 2012-01-17
# success
# crawling 2012-01-18
# success
# crawling 2012-01-19
# fail, check if it is a holiday
# crawling 2012-01-20
# fail, check if it is a holiday
# crawling 2012-01-21
# fail, check if it is a holiday
# crawling 2012-01-22
# fail, check if it is a holiday
# crawling 2012-01-23
# fail, check if it is a holiday
# crawling 2012-01-24
# fail, check if it is a holiday
# crawling 2012-01-25
# fail, check if it is a holiday
# crawling 2012-01-26
# fail, check if it is a holiday
# crawling 2012-01-27
# fail, check if it is a holiday
# crawling 2012-01-28
# fail, check if it is a holiday
# crawling 2012-01-29
# fail, check if it is a holiday
# crawling 2012-01-30
# success
# crawling 2012-01-31
# success
# crawling 2012-02-01
# success
# crawling 2012-02-02
# success
# crawling 2012-02-03
# success
# crawling 2012-02-04
# success
# crawling 2012-02-05
# fail, check if it is a holiday
# crawling 2012-02-06
# success
# crawling 2012-02-07
# success
# crawling 2012-02-08
# success
# crawling 2012-02-09
# success
# crawling 2012-02-10
# success
# crawling 2012-02-11
# fail, check if it is a holiday
# crawling 2012-02-12
# fail, check if it is a holiday
# crawling 2012-02-13
# success
# crawling 2012-02-14
# success
# crawling 2012-02-15
# success
# crawling 2012-02-16
# success
# crawling 2012-02-17
# success
# crawling 2012-02-18
# fail, check if it is a holiday
# crawling 2012-02-19
# fail, check if it is a holiday
# crawling 2012-02-20
# success
# crawling 2012-02-21
# success
# crawling 2012-02-22
# success
# crawling 2012-02-23
# success
# crawling 2012-02-24
# success
# crawling 2012-02-25
# fail, check if it is a holiday
# crawling 2012-02-26
# fail, check if it is a holiday
# crawling 2012-02-27
# fail, check if it is a holiday
# crawling 2012-02-28
# fail, check if it is a holiday
# crawling 2012-02-29
# success
# crawling 2012-03-01
# success
# crawling 2012-03-02
# success
# crawling 2012-03-03
# success
# crawling 2012-03-04
# fail, check if it is a holiday
# crawling 2012-03-05
# success
# crawling 2012-03-06
# success
# crawling 2012-03-07
# success
# crawling 2012-03-08
# success
# crawling 2012-03-09
# success
# crawling 2012-03-10
# fail, check if it is a holiday
# crawling 2012-03-11
# fail, check if it is a holiday
# crawling 2012-03-12
# success
# crawling 2012-03-13
# success
# crawling 2012-03-14
# success
# crawling 2012-03-15
# success
# crawling 2012-03-16
# success
# crawling 2012-03-17
# fail, check if it is a holiday
# crawling 2012-03-18
# fail, check if it is a holiday
# crawling 2012-03-19
# success
# crawling 2012-03-20
# success
# crawling 2012-03-21
# success
# crawling 2012-03-22
# success
# crawling 2012-03-23
# success
# crawling 2012-03-24
# fail, check if it is a holiday
# crawling 2012-03-25
# fail, check if it is a holiday
# crawling 2012-03-26
# success
# crawling 2012-03-27
# success
# crawling 2012-03-28
# success
# crawling 2012-03-29
# success
# crawling 2012-03-30
# success
# crawling 2012-03-31
# fail, check if it is a holiday
# crawling 2012-04-01
# fail, check if it is a holiday
# crawling 2012-04-02
# success
# crawling 2012-04-03
# success
# crawling 2012-04-04
# fail, check if it is a holiday
# crawling 2012-04-05
# success
# crawling 2012-04-06
# success
# crawling 2012-04-07
# fail, check if it is a holiday
# crawling 2012-04-08
# fail, check if it is a holiday
# crawling 2012-04-09
# success
# crawling 2012-04-10
# success
# crawling 2012-04-11
# success
# crawling 2012-04-12
# success
# save 0
# crawling 2012-04-13
# success
# crawling 2012-04-14
# fail, check if it is a holiday
# crawling 2012-04-15
# fail, check if it is a holiday
# crawling 2012-04-16
# success
# crawling 2012-04-17
# success
# crawling 2012-04-18
# success
# crawling 2012-04-19
# success
# crawling 2012-04-20
# success
# crawling 2012-04-21
# fail, check if it is a holiday
# crawling 2012-04-22
# fail, check if it is a holiday
# crawling 2012-04-23
# success
# crawling 2012-04-24
# success
# crawling 2012-04-25
# success
# crawling 2012-04-26
# success
# crawling 2012-04-27
# success
# crawling 2012-04-28
# fail, check if it is a holiday
# crawling 2012-04-29
# fail, check if it is a holiday
# crawling 2012-04-30
# success
# crawling 2012-05-01
# fail, check if it is a holiday
# crawling 2012-05-02
# success
# crawling 2012-05-03
# success
# crawling 2012-05-04
# success
# crawling 2012-05-05
# fail, check if it is a holiday
# crawling 2012-05-06
# fail, check if it is a holiday
# crawling 2012-05-07
# success
# crawling 2012-05-08
# success
# crawling 2012-05-09
# success
# crawling 2012-05-10
# success
# crawling 2012-05-11
# success
# crawling 2012-05-12
# fail, check if it is a holiday
# crawling 2012-05-13
# fail, check if it is a holiday
# crawling 2012-05-14
# success
# crawling 2012-05-15
# success
# crawling 2012-05-16
# success
# crawling 2012-05-17
# success
# crawling 2012-05-18
# success
# crawling 2012-05-19
# fail, check if it is a holiday
# crawling 2012-05-20
# fail, check if it is a holiday
# crawling 2012-05-21
# success
# crawling 2012-05-22
# success
# crawling 2012-05-23
# success
# crawling 2012-05-24
# success
# crawling 2012-05-25
# success
# crawling 2012-05-26
# fail, check if it is a holiday
# crawling 2012-05-27
# fail, check if it is a holiday
# crawling 2012-05-28
# success
# crawling 2012-05-29
# success
# crawling 2012-05-30
# success
# crawling 2012-05-31
# success
# crawling 2012-06-01
# success
# crawling 2012-06-02
# fail, check if it is a holiday
# crawling 2012-06-03
# fail, check if it is a holiday
# crawling 2012-06-04
# success
# crawling 2012-06-05
# success
# crawling 2012-06-06
# success
# crawling 2012-06-07
# success
# crawling 2012-06-08
# success
# crawling 2012-06-09
# fail, check if it is a holiday
# crawling 2012-06-10
# fail, check if it is a holiday
# crawling 2012-06-11
# success
# crawling 2012-06-12
# success
# crawling 2012-06-13
# success
# crawling 2012-06-14
# success
# crawling 2012-06-15
# success
# crawling 2012-06-16
# fail, check if it is a holiday
# crawling 2012-06-17
# fail, check if it is a holiday
# crawling 2012-06-18
# success
# crawling 2012-06-19
# success
# crawling 2012-06-20
# success
# crawling 2012-06-21
# success
# crawling 2012-06-22
# success
# crawling 2012-06-23
# fail, check if it is a holiday
# crawling 2012-06-24
# fail, check if it is a holiday
# crawling 2012-06-25
# success
# crawling 2012-06-26
# success
# crawling 2012-06-27
# success
# crawling 2012-06-28
# success
# crawling 2012-06-29
# success
# crawling 2012-06-30
# fail, check if it is a holiday
# crawling 2012-07-01
# fail, check if it is a holiday
# crawling 2012-07-02
# success
# crawling 2012-07-03
# success
# crawling 2012-07-04
# success
# crawling 2012-07-05
# success
# save 0
# crawling 2012-07-06
# success
# crawling 2012-07-07
# fail, check if it is a holiday
# crawling 2012-07-08
# fail, check if it is a holiday
# crawling 2012-07-09
# success
# crawling 2012-07-10
# success
# crawling 2012-07-11
# success
# crawling 2012-07-12
# success
# crawling 2012-07-13
# success
# crawling 2012-07-14
# fail, check if it is a holiday
# crawling 2012-07-15
# fail, check if it is a holiday
# crawling 2012-07-16
# success
# crawling 2012-07-17
# success
# crawling 2012-07-18
# success
# crawling 2012-07-19
# success
# crawling 2012-07-20
# success
# crawling 2012-07-21
# fail, check if it is a holiday
# crawling 2012-07-22
# fail, check if it is a holiday
# crawling 2012-07-23
# success
# crawling 2012-07-24
# success
# crawling 2012-07-25
# success
# crawling 2012-07-26
# success
# crawling 2012-07-27
# success
# crawling 2012-07-28
# fail, check if it is a holiday
# crawling 2012-07-29
# fail, check if it is a holiday
# crawling 2012-07-30
# success
# crawling 2012-07-31
# success
# crawling 2012-08-01
# success
# crawling 2012-08-02
# fail, check if it is a holiday
# crawling 2012-08-03
# success
# crawling 2012-08-04
# fail, check if it is a holiday
# crawling 2012-08-05
# fail, check if it is a holiday
# crawling 2012-08-06
# success
# crawling 2012-08-07
# success
# crawling 2012-08-08
# success
# crawling 2012-08-09
# success
# crawling 2012-08-10
# success
# crawling 2012-08-11
# fail, check if it is a holiday
# crawling 2012-08-12
# fail, check if it is a holiday
# crawling 2012-08-13
# success
# crawling 2012-08-14
# success
# crawling 2012-08-15
# success
# crawling 2012-08-16
# success
# crawling 2012-08-17
# success
# crawling 2012-08-18
# fail, check if it is a holiday
# crawling 2012-08-19
# fail, check if it is a holiday
# crawling 2012-08-20
# success
# crawling 2012-08-21
# success
# crawling 2012-08-22
# success
# crawling 2012-08-23
# success
# crawling 2012-08-24
# success
# crawling 2012-08-25
# fail, check if it is a holiday
# crawling 2012-08-26
# fail, check if it is a holiday
# crawling 2012-08-27
# success
# crawling 2012-08-28
# success
# crawling 2012-08-29
# success
# crawling 2012-08-30
# success
# crawling 2012-08-31
# success
# crawling 2012-09-01
# fail, check if it is a holiday
# crawling 2012-09-02
# fail, check if it is a holiday
# crawling 2012-09-03
# success
# crawling 2012-09-04
# success
# crawling 2012-09-05
# success
# crawling 2012-09-06
# success
# crawling 2012-09-07
# success
# crawling 2012-09-08
# fail, check if it is a holiday
# crawling 2012-09-09
# fail, check if it is a holiday
# crawling 2012-09-10
# success
# crawling 2012-09-11
# success
# crawling 2012-09-12
# success
# crawling 2012-09-13
# success
# crawling 2012-09-14
# success
# crawling 2012-09-15
# fail, check if it is a holiday
# crawling 2012-09-16
# fail, check if it is a holiday
# crawling 2012-09-17
# success
# crawling 2012-09-18
# success
# crawling 2012-09-19
# success
# crawling 2012-09-20
# success
# crawling 2012-09-21
# success
# crawling 2012-09-22
# fail, check if it is a holiday
# crawling 2012-09-23
# fail, check if it is a holiday
# crawling 2012-09-24
# success
# crawling 2012-09-25
# success
# crawling 2012-09-26
# success
# crawling 2012-09-27
# success
# save 0
# crawling 2012-09-28
# success
# crawling 2012-09-29
# fail, check if it is a holiday
# crawling 2012-09-30
# fail, check if it is a holiday
# crawling 2012-10-01
# success
# crawling 2012-10-02
# success
# crawling 2012-10-03
# success
# crawling 2012-10-04
# success
# crawling 2012-10-05
# success
# crawling 2012-10-06
# fail, check if it is a holiday
# crawling 2012-10-07
# fail, check if it is a holiday
# crawling 2012-10-08
# success
# crawling 2012-10-09
# success
# crawling 2012-10-10
# fail, check if it is a holiday
# crawling 2012-10-11
# success
# crawling 2012-10-12
# success
# crawling 2012-10-13
# fail, check if it is a holiday
# crawling 2012-10-14
# fail, check if it is a holiday
# crawling 2012-10-15
# success
# crawling 2012-10-16
# success
# crawling 2012-10-17
# success
# crawling 2012-10-18
# success
# crawling 2012-10-19
# success
# crawling 2012-10-20
# fail, check if it is a holiday
# crawling 2012-10-21
# fail, check if it is a holiday
# crawling 2012-10-22
# success
# crawling 2012-10-23
# success
# crawling 2012-10-24
# success
# crawling 2012-10-25
# success
# crawling 2012-10-26
# success
# crawling 2012-10-27
# fail, check if it is a holiday
# crawling 2012-10-28
# fail, check if it is a holiday
# crawling 2012-10-29
# success
# crawling 2012-10-30
# success
# crawling 2012-10-31
# success
# crawling 2012-11-01
# success
# crawling 2012-11-02
# success
# crawling 2012-11-03
# fail, check if it is a holiday
# crawling 2012-11-04
# fail, check if it is a holiday
# crawling 2012-11-05
# success
# crawling 2012-11-06
# success
# crawling 2012-11-07
# success
# crawling 2012-11-08
# success
# crawling 2012-11-09
# success
# crawling 2012-11-10
# fail, check if it is a holiday
# crawling 2012-11-11
# fail, check if it is a holiday
# crawling 2012-11-12
# success
# crawling 2012-11-13
# success
# crawling 2012-11-14
# success
# crawling 2012-11-15
# success
# crawling 2012-11-16
# success
# crawling 2012-11-17
# fail, check if it is a holiday
# crawling 2012-11-18
# fail, check if it is a holiday
# crawling 2012-11-19
# success
# crawling 2012-11-20
# success
# crawling 2012-11-21
# success
# crawling 2012-11-22
# success
# crawling 2012-11-23
# success
# crawling 2012-11-24
# fail, check if it is a holiday
# crawling 2012-11-25
# fail, check if it is a holiday
# crawling 2012-11-26
# success
# crawling 2012-11-27
# success
# crawling 2012-11-28
# success
# crawling 2012-11-29
# success
# crawling 2012-11-30
# success
# crawling 2012-12-01
# fail, check if it is a holiday
# crawling 2012-12-02
# fail, check if it is a holiday
# crawling 2012-12-03
# success
# crawling 2012-12-04
# success
# crawling 2012-12-05
# success
# crawling 2012-12-06
# success
# crawling 2012-12-07
# success
# crawling 2012-12-08
# fail, check if it is a holiday
# crawling 2012-12-09
# fail, check if it is a holiday
# crawling 2012-12-10
# success
# crawling 2012-12-11
# success
# crawling 2012-12-12
# success
# crawling 2012-12-13
# success
# crawling 2012-12-14
# success
# crawling 2012-12-15
# fail, check if it is a holiday
# crawling 2012-12-16
# fail, check if it is a holiday
# crawling 2012-12-17
# success
# crawling 2012-12-18
# success
# crawling 2012-12-19
# success
# crawling 2012-12-20
# success
# save 0
# crawling 2012-12-21
# success
# crawling 2012-12-22
# success
# crawling 2012-12-23
# fail, check if it is a holiday
# crawling 2012-12-24
# success
# crawling 2012-12-25
# success
# crawling 2012-12-26
# success
# crawling 2012-12-27
# success
# crawling 2012-12-28
# success
# crawling 2012-12-29
# fail, check if it is a holiday
# crawling 2012-12-30
# fail, check if it is a holiday
# crawling 2012-12-31
# fail, check if it is a holiday

# %% [markdown]
# # 時間區間範例：

# %%
import datetime
print('2010年抓取財報的時間點是')
season_range(datetime.date(2010,1,1), datetime.date(2011,1,1))

# %% [markdown]
# # 每季財報 時間區間補充：
#
# 關於每季財報爬取，選取的時間範圍要「包含」以下時段，就能夠爬到截止日期的財報囉！例如：
#
# * 2010年3月31號 --> 2009 第四季
# * 2010年5月15號 --> 2010 第一季
# * 2010年8月14號 --> 2010 第二季
# * 2010年11月14號 --> 2010 第三季
#
# 所以假如我們想要抓2018年的第一季，就可以輸入一個時間範圍，例如：
#
# * 2018年5月01號 到 2018年5月31號
#
# 因為這段時間有包含 2018年5月15號，所以就會下載 2018年第一季的財報喔！

# %% [markdown]
# # 程式化更新資料

# %%
import datetime
from finlab.crawler import update_table
update_table(conn, 'price', crawl_price, [datetime.date(2019,12,29)])
update_table(conn, 'monthly_revenue', crawl_monthly_report, [datetime.date(2019,12,29)])
update_table(conn, 'finance_statement', crawl_finance_statement_by_date, [datetime.date(2019,12,29)])
# Out:
# start crawl price from  2019-12-29 to 2019-12-29
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# crawling 2019-12-29
# fail, check if it is a holiday
#
# start crawl monthly_revenue from  2019-12-29 to 2019-12-29
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# crawling 2019-12-29
# https://mops.twse.com.tw/nas/t21/sii/t21sc03_108_12.html
# **WARRN: Pandas cannot find any table in the HTML file
# fail, check if it is a holiday
